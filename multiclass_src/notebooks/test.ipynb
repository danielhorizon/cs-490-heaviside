# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import tensorboard as tb
import tensorflow as tf 

from tensorflow.python.summary.summary_iterator import summary_iterator
from matplotlib import pyplot as plt
from scipy import stats

# %%
path = "/home/tdl29/cs-490-heaviside/multiclass_src/tensorboard/baseline-ce-0/events.out.tfevents.1605392097.34dafb52bef4.8822.0"
for e in tf.compat.v1.train.summary_iterator(path):
    print(e)
# Out:
# wall_time: 1605392097.8795836
# file_version: "brain.Event:2"
#
# wall_time: 1605392097.8858826
# summary {
#   value {
#     tag: "loss"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8859286
# summary {
#   value {
#     tag: "train/accuracy"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8859515
# summary {
#   value {
#     tag: "train/w-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8859723
# summary {
#   value {
#     tag: "train/micro-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8859923
# summary {
#   value {
#     tag: "train/macro-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8860118
# summary {
#   value {
#     tag: "train/w-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8860316
# summary {
#   value {
#     tag: "train/micro-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8860514
# summary {
#   value {
#     tag: "train/macro-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8860707
# summary {
#   value {
#     tag: "train/w-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8860905
# summary {
#   value {
#     tag: "train/micro-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.88611
# summary {
#   value {
#     tag: "train/macro-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8862152
# summary {
#   value {
#     tag: "train/class-0-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8863304
# summary {
#   value {
#     tag: "train/class-0-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8864338
# summary {
#   value {
#     tag: "train/class-0-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8866546
# summary {
#   value {
#     tag: "train/class-1-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8867671
# summary {
#   value {
#     tag: "train/class-1-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8868606
# summary {
#   value {
#     tag: "train/class-1-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8869503
# summary {
#   value {
#     tag: "train/class-2-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.887038
# summary {
#   value {
#     tag: "train/class-2-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8871248
# summary {
#   value {
#     tag: "train/class-2-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8872123
# summary {
#   value {
#     tag: "train/class-3-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8873003
# summary {
#   value {
#     tag: "train/class-3-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8873878
# summary {
#   value {
#     tag: "train/class-3-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.887535
# summary {
#   value {
#     tag: "train/class-4-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8876526
# summary {
#   value {
#     tag: "train/class-4-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8877676
# summary {
#   value {
#     tag: "train/class-4-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8878841
# summary {
#   value {
#     tag: "train/class-5-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8879964
# summary {
#   value {
#     tag: "train/class-5-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8881068
# summary {
#   value {
#     tag: "train/class-5-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8882213
# summary {
#   value {
#     tag: "train/class-6-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8883307
# summary {
#   value {
#     tag: "train/class-6-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8884413
# summary {
#   value {
#     tag: "train/class-6-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8885555
# summary {
#   value {
#     tag: "train/class-7-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8886604
# summary {
#   value {
#     tag: "train/class-7-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8888292
# summary {
#   value {
#     tag: "train/class-7-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8889515
# summary {
#   value {
#     tag: "train/class-8-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8890762
# summary {
#   value {
#     tag: "train/class-8-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8891978
# summary {
#   value {
#     tag: "train/class-8-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8893192
# summary {
#   value {
#     tag: "train/class-9-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.8894398
# summary {
#   value {
#     tag: "train/class-9-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392097.889558
# summary {
#   value {
#     tag: "train/class-9-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.2761555
# summary {
#   value {
#     tag: "test/accuracy"
#     simple_value: 0.08139999955892563
#   }
# }
#
# wall_time: 1605392101.2762249
# summary {
#   value {
#     tag: "test/micro-f1"
#     simple_value: 0.08139999955892563
#   }
# }
#
# wall_time: 1605392101.27625
# summary {
#   value {
#     tag: "test/macro-f1"
#     simple_value: 0.03761294484138489
#   }
# }
#
# wall_time: 1605392101.276273
# summary {
#   value {
#     tag: "test/w-f1"
#     simple_value: 0.03761294484138489
#   }
# }
#
# wall_time: 1605392101.2763197
# summary {
#   value {
#     tag: "test/class-0-f1"
#     simple_value: 0.09278462827205658
#   }
# }
#
# wall_time: 1605392101.2763543
# summary {
#   value {
#     tag: "test/class-0-precision"
#     simple_value: 0.06380423158407211
#   }
# }
#
# wall_time: 1605392101.276388
# summary {
#   value {
#     tag: "test/class-0-recall"
#     simple_value: 0.17000000178813934
#   }
# }
#
# wall_time: 1605392101.4074256
# summary {
#   value {
#     tag: "test/class-0-TP"
#     simple_value: 850.0
#   }
# }
#
# wall_time: 1605392101.407538
# summary {
#   value {
#     tag: "test/class-0-FP"
#     simple_value: 12472.0
#   }
# }
#
# wall_time: 1605392101.407562
# summary {
#   value {
#     tag: "test/class-0-FN"
#     simple_value: 4150.0
#   }
# }
#
# wall_time: 1605392101.4075847
# summary {
#   value {
#     tag: "test/class-0-TN"
#     simple_value: 3220.0
#   }
# }
#
# wall_time: 1605392101.4076412
# summary {
#   value {
#     tag: "test/class-1-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.407676
# summary {
#   value {
#     tag: "test/class-1-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.407709
# summary {
#   value {
#     tag: "test/class-1-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.5230465
# summary {
#   value {
#     tag: "test/class-1-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.5231164
# summary {
#   value {
#     tag: "test/class-1-FP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.5231407
# summary {
#   value {
#     tag: "test/class-1-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392101.5231633
# summary {
#   value {
#     tag: "test/class-1-TN"
#     simple_value: 4070.0
#   }
# }
#
# wall_time: 1605392101.5232184
# summary {
#   value {
#     tag: "test/class-2-f1"
#     simple_value: 0.023112768307328224
#   }
# }
#
# wall_time: 1605392101.5232525
# summary {
#   value {
#     tag: "test/class-2-precision"
#     simple_value: 0.1698630154132843
#   }
# }
#
# wall_time: 1605392101.5232859
# summary {
#   value {
#     tag: "test/class-2-recall"
#     simple_value: 0.012400000356137753
#   }
# }
#
# wall_time: 1605392101.6399796
# summary {
#   value {
#     tag: "test/class-2-TP"
#     simple_value: 62.0
#   }
# }
#
# wall_time: 1605392101.640039
# summary {
#   value {
#     tag: "test/class-2-FP"
#     simple_value: 303.0
#   }
# }
#
# wall_time: 1605392101.6400607
# summary {
#   value {
#     tag: "test/class-2-FN"
#     simple_value: 4938.0
#   }
# }
#
# wall_time: 1605392101.640081
# summary {
#   value {
#     tag: "test/class-2-TN"
#     simple_value: 4008.0
#   }
# }
#
# wall_time: 1605392101.640133
# summary {
#   value {
#     tag: "test/class-3-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.6401644
# summary {
#   value {
#     tag: "test/class-3-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.6401937
# summary {
#   value {
#     tag: "test/class-3-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.7633512
# summary {
#   value {
#     tag: "test/class-3-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.76341
# summary {
#   value {
#     tag: "test/class-3-FP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.7634325
# summary {
#   value {
#     tag: "test/class-3-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392101.7634575
# summary {
#   value {
#     tag: "test/class-3-TN"
#     simple_value: 4070.0
#   }
# }
#
# wall_time: 1605392101.763513
# summary {
#   value {
#     tag: "test/class-4-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.7635438
# summary {
#   value {
#     tag: "test/class-4-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.7635734
# summary {
#   value {
#     tag: "test/class-4-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.8810418
# summary {
#   value {
#     tag: "test/class-4-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392101.8810916
# summary {
#   value {
#     tag: "test/class-4-FP"
#     simple_value: 2.0
#   }
# }
#
# wall_time: 1605392101.8811147
# summary {
#   value {
#     tag: "test/class-4-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392101.8811374
# summary {
#   value {
#     tag: "test/class-4-TN"
#     simple_value: 4070.0
#   }
# }
#
# wall_time: 1605392101.8811991
# summary {
#   value {
#     tag: "test/class-5-f1"
#     simple_value: 0.14620500802993774
#   }
# }
#
# wall_time: 1605392101.8812332
# summary {
#   value {
#     tag: "test/class-5-precision"
#     simple_value: 0.08655332028865814
#   }
# }
#
# wall_time: 1605392101.8812664
# summary {
#   value {
#     tag: "test/class-5-recall"
#     simple_value: 0.47040000557899475
#   }
# }
#
# wall_time: 1605392102.00471
# summary {
#   value {
#     tag: "test/class-5-TP"
#     simple_value: 2352.0
#   }
# }
#
# wall_time: 1605392102.0047574
# summary {
#   value {
#     tag: "test/class-5-FP"
#     simple_value: 24822.0
#   }
# }
#
# wall_time: 1605392102.0047805
# summary {
#   value {
#     tag: "test/class-5-FN"
#     simple_value: 2648.0
#   }
# }
#
# wall_time: 1605392102.004802
# summary {
#   value {
#     tag: "test/class-5-TN"
#     simple_value: 1718.0
#   }
# }
#
# wall_time: 1605392102.0048578
# summary {
#   value {
#     tag: "test/class-6-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.0048912
# summary {
#   value {
#     tag: "test/class-6-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.0049229
# summary {
#   value {
#     tag: "test/class-6-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.1219354
# summary {
#   value {
#     tag: "test/class-6-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.1219847
# summary {
#   value {
#     tag: "test/class-6-FP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.1220086
# summary {
#   value {
#     tag: "test/class-6-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392102.1220317
# summary {
#   value {
#     tag: "test/class-6-TN"
#     simple_value: 4070.0
#   }
# }
#
# wall_time: 1605392102.1221018
# summary {
#   value {
#     tag: "test/class-7-f1"
#     simple_value: 0.11402702331542969
#   }
# }
#
# wall_time: 1605392102.1221344
# summary {
#   value {
#     tag: "test/class-7-precision"
#     simple_value: 0.0882127583026886
#   }
# }
#
# wall_time: 1605392102.1221662
# summary {
#   value {
#     tag: "test/class-7-recall"
#     simple_value: 0.16120000183582306
#   }
# }
#
# wall_time: 1605392102.2405148
# summary {
#   value {
#     tag: "test/class-7-TP"
#     simple_value: 806.0
#   }
# }
#
# wall_time: 1605392102.2405686
# summary {
#   value {
#     tag: "test/class-7-FP"
#     simple_value: 8331.0
#   }
# }
#
# wall_time: 1605392102.2405937
# summary {
#   value {
#     tag: "test/class-7-FN"
#     simple_value: 4194.0
#   }
# }
#
# wall_time: 1605392102.2406173
# summary {
#   value {
#     tag: "test/class-7-TN"
#     simple_value: 3264.0
#   }
# }
#
# wall_time: 1605392102.2406769
# summary {
#   value {
#     tag: "test/class-8-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.2407126
# summary {
#   value {
#     tag: "test/class-8-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.2411056
# summary {
#   value {
#     tag: "test/class-8-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.3571754
# summary {
#   value {
#     tag: "test/class-8-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.3572276
# summary {
#   value {
#     tag: "test/class-8-FP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.3572516
# summary {
#   value {
#     tag: "test/class-8-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392102.3572745
# summary {
#   value {
#     tag: "test/class-8-TN"
#     simple_value: 4070.0
#   }
# }
#
# wall_time: 1605392102.3573349
# summary {
#   value {
#     tag: "test/class-9-f1"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.3573697
# summary {
#   value {
#     tag: "test/class-9-precision"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.3580413
# summary {
#   value {
#     tag: "test/class-9-recall"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.4749115
# summary {
#   value {
#     tag: "test/class-9-TP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.474979
# summary {
#   value {
#     tag: "test/class-9-FP"
#     simple_value: 0.0
#   }
# }
#
# wall_time: 1605392102.4750037
# summary {
#   value {
#     tag: "test/class-9-FN"
#     simple_value: 5000.0
#   }
# }
#
# wall_time: 1605392102.4750268
# summary {
#   value {
#     tag: "test/class-9-TN"
#     simple_value: 4070.0
#   }
# }
